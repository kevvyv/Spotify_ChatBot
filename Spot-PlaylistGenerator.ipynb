# %%
import requests
from urllib.parse import urlencode
import base64
import webbrowser

# %%
client_id = "8ee52223276f4b7d9092ebb7d59e5205"
client_secret = "e3be9899d7464676b3d8124f400f73af"

# %%
auth_headers = {
    "client_id": client_id,
    "response_type": "code",
    "redirect_uri": "http://localhost:7777/callback",
    "scope": "user-library-read"
}

webbrowser.open("https://accounts.spotify.com/authorize?" + urlencode(auth_headers))
# Out:
# True

# %%
code = "AQCAi5_EBtLmW5BGevWgyqwOskPreavYDf8bLrn96qYqekxhwT60Cd2ndk28K58fDd9K8vm4jD5TGAqo80WQF2277QSMoGVpdMPZgL9XXPGsICt74VaYMpsSUzCF67xFj1yBdTeVSXdxuX6EaBxlfNDjNtnUeo34nariI3BMr7uckJHlEDXKuctINwQaDdnaxiCQdpU"

# %%
encoded_credentials = base64.b64encode(client_id.encode() + b':' + client_secret.encode()).decode("utf-8")

token_headers = {
    "Authorization": "Basic " + encoded_credentials,
    "Content-Type": "application/x-www-form-urlencoded"
}

token_data = {
    "grant_type": "authorization_code",
    "code": code,
    "redirect_uri": "http://localhost:7777/callback"
}

r = requests.post("https://accounts.spotify.com/api/token", data=token_data, headers=token_headers)

# %%
token = r.json()["access_token"]

print(token)
# Out:
# BQCuWdoonbPp9QamhH3DVP_kmBmNgpucXXLEKfpKolLkHp5fcEUOIa12KR-B7_pg8b0EFXJ-P6gNDXXe4gpm8pikzIjpT539V3SvtM9XhCMNt3GhEs91EiFNo8VR5qXNPlyaHNrvLRt1pKSvHMkn9QrHsB5CvoUQQ8TUg6XwqGuY5ac1lUQwIDQ8YcEeuUgu7NB_eRoLA_u1CStY_8Q

# %%
token = "BQCuWdoonbPp9QamhH3DVP_kmBmNgpucXXLEKfpKolLkHp5fcEUOIa12KR-B7_pg8b0EFXJ-P6gNDXXe4gpm8pikzIjpT539V3SvtM9XhCMNt3GhEs91EiFNo8VR5qXNPlyaHNrvLRt1pKSvHMkn9QrHsB5CvoUQQ8TUg6XwqGuY5ac1lUQwIDQ8YcEeuUgu7NB_eRoLA_u1CStY_8Q"

# %%
# !pip install spotipy
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/250.3 kB ? eta -:--:--
#    --------------------------- ------------ 174.1/250.3 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  245.8/250.3 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 250.3/250.3 kB 2.6 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import numpy as np

cid = '8ee52223276f4b7d9092ebb7d59e5205'
secret = 'e3be9899d7464676b3d8124f400f73af'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager
=
client_credentials_manager)
redirect_uri = "http://localhost:7777/callback"

# %%
scope1 = 'user-read-recently-played'
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=cid,
                                               client_secret=secret,
                                               redirect_uri=redirect_uri,
                                               scope=scope1))

# %%
name = "Drake" #chosen artist
result = sp.search(name) #search query
result
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Drake&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#        'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#        'id': '3TVXtAsR1Inumwj472S9r4',
#        'name': 'Drake',
#        'type': 'artist',
#        'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
# ...

# %%
result = sp.search("Drake")
track = result['tracks']['items'][0]

artist = sp.artist(track["artists"][0]["external_urls"]["spotify"])
print("artist genres:", artist["genres"])

album = sp.album(track["album"]["external_urls"]["spotify"])
print("album genres:", album["genres"])
print("album release-date:", album["release_date"])
# Out:
# artist genres: ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap']
# album genres: []
# album release-date: 2018-06-29

# %%
track['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#   'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#   'id': '3TVXtAsR1Inumwj472S9r4',
#   'name': 'Drake',
#   'type': 'artist',
#   'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}]

# %%
def getGenres()

# %%
#Fetch recent tracks
results = sp.current_user_recently_played(limit=50)

#Initialize lists to store data
artist_names = []
track_names = []
genres = []

#Extract required data
for item in results['items']:
    track = item['track']
    artist_names.append(track['artists'][0]['name'])
    track_names.append(track['name'])

#Fetching the genre requires an extra API call per artist
    artist_id = track['artists'][0]['id']
    artist = sp.artist(artist_id)
    genre = artist['genres'][0] if artist['genres'] else 'Unknown'  # Take the first genre or 'Unknown'
    genres.append(genre)

#Create DataFrame
df = pd.DataFrame({
    'Artist Name': artist_names,
    'Track Name': track_names,
    'Genre': genres
})

df
# Out:
#          Artist Name                                         Track Name  \
# 0       Brent Faiyaz                                          Best Time
# 1               Saba  an Interlude Called “Circus” (feat. Eryn Allen...
# 2         Larry June                                 Watering My Plants
# 3          Aaron May                                            Make It
# 4               MAVI                                     Love, of Money
# 5              4batz                                   act ii: date @ 8
# 6       Brent Faiyaz               Upset (feat. Tommy Richman & FELIX!)
# 7       Chase Shakur      i don't wanna fall in love, it's too late now
# 8              4batz                               act i: stickerz "99"
# 9           Kyle Lux                                      Say It's Fine
# 10         Fiji Blue                                        Butterflies
# 11     Weston Estate                                             Slowly
# ...

# %%
artists = set(list(df.get("Artist Name")))

# %%
genres = []
for song in artists:
    result = sp.search(song)
    track = result['tracks']['items'][0]

    artist = sp.artist(track["artists"][0]["external_urls"]["spotify"])
    print("added " + song)
    genres.append(artist['genres'])

    album = sp.album(track["album"]["external_urls"]["spotify"])
    #print("album genres:", album["genres"])
    #print("album release-date:", album["release_date"])
# Out:
# added 4batz
# added Aaron May
# added Fiji Blue
# added Dreamer Boy
# added A-Wall
# added Peter Fenn
# added MAVI
# added Brent Faiyaz
# added Kyle Lux
# added Superfan
# added Jakob
# added The Hails
# added Personal Trainer
# added bbno$
# added Grady
# added Hadji Gaviota
# added Lilacs.
# added Teenage Priest
# added Weston Estate
# added Tom The Mail Man
# added Postcard Boy
# added Spencer.
# added stupid rich kid
# added Larry June
# added Chase Shakur
# added Saba
# added Brent de la Cruz
# added WILLIS

# %%
genres
# Out:
# [[],
#  [],
#  ['chill pop', 'chill r&b'],
#  ['nashville indie'],
#  [],
#  ['la pop'],
#  ['alternative hip hop', 'chill abstract hip hop', 'indie hip hop'],
#  ['r&b', 'rap'],
#  ['chill r&b', 'indie r&b'],
#  ['modern indie pop'],
#  ['bedroom pop'],
#  ['gainesville indie'],
#  ['bongo flava', 'tanzanian hip hop', 'tanzanian pop'],
#  ['canadian hip hop', 'dark trap', 'meme rap'],
#  ['indie electropop'],
#  [],
#  ['dark synthpop'],
#  ['bedroom pop'],
#  [],
#  ['modern indie pop'],
#  [],
#  ['bedroom pop'],
#  [],
#  ['cali rap'],
#  [],
#  ['mexican hip hop', 'sad sierreno', 'tamaulipas rap'],
#  [],
#  ['alabama indie']]
